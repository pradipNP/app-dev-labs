# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("house_price_small_dataset2.csv")
df.columns = ["Size", "Price"]
df
# Out:
#    Size   Price
# 0  1360  227969
# 1  1794  262101
# 2  1630  271052
# 3  1595  213147
# 4  2138  338848
# 5  2669  373833
# 6   966  143455
# 7  1738  227859
# 8   830  154577

# %%
# %matplotlib inline
plt.xlabel("Size (sq ft)")
plt.ylabel("Price ($)")
plt.title("Simple Linear Regression")
plt.scatter(df.Size, df.Price, color="blue", marker="+", label="data points")
plt.plot(df.Size, reg.predict(df[["Size"]]), color = 'red', label="Predicted Linear regression")
plt.legend()
plt.show()

# %% [markdown]
# # Let's Predict for new input(size) and ask for output(price)

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Size']],df.Price) # Features are always in 2D array and the target in 1D
# Out:
# LinearRegression()

# %%
df
# Out:
#    Size   Price
# 0  1360  227969
# 1  1794  262101
# 2  1630  271052
# 3  1595  213147
# 4  2138  338848
# 5  2669  373833
# 6   966  143455
# 7  1738  227859
# 8   830  154577

# %%
reg.predict([[830]])  # (x)
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([141497.81936926])

# %%
# coefficient value(Slope(m))
reg.coef_
# Out:
# array([129.56698285])

# %%
reg.intercept_ # (b)
# Out:
# 33957.22360213107

# %%
# We know y = m*x+b: m=slope & b=intercept
# to predict y, let's calculate mathematically
129.56698285*830+33957.22360213107
# Out:
# 141497.81936763105

# %% [markdown]
# # Let's create another CSV file which contain only size and Predict the prices for all sizes

# %%
size = { "Size": [1000, 1100, 1200, 3000, 4000, 5000]}
d = pd.DataFrame(size)
d.to_csv("only_size.csv", index=False)

# %%
data = pd.read_csv("only_size.csv")
data
# Out:
#    Size
# 0  1000
# 1  1100
# 2  1200
# 3  3000
# 4  4000
# 5  5000

# %%
p = reg.predict(data)

# %%
data['Prices'] = p
data
# Out:
#    Size         Prices
# 0  1000  163524.206454
# 1  1100  176480.904739
# 2  1200  189437.603024
# 3  3000  422658.172158
# 4  4000  552225.155010
# 5  5000  681792.137862

# %%
data.to_csv("PredictionValue_ofSize.csv")
